# %% [markdown]
# # U.S. Medical Insurance Costs

# %% [markdown]
# The goal of this project was to analyze the 'insurance.csv' file containing U.S. Medical Insurance Costs.

# %% [markdown]
# ## Dissecting the file

# %% [markdown]
# The file is made of seven columns which contain:
# - Age
# - Sex
# - BMI
# - Number of children
# - Smoker status
# - Region
# - Charges
#
# There are 1338 rows of data.
#
# There is no missing data, and the data appears to be "realistic". For example, the "age" column has no negative values or values bigger than a normal person's lifespan.

# %% [markdown]
#  ## Expectations

# %% [markdown]
# - <strong>Age<strong>
#
# Elderly individuals may be subject to higher insurance premiums, followed by adults and then by younger individuals.
#
# - <strong>Sex<strong>
#
# Charging different insurance rates based on gender is illegal under the Affordable Care Act (ACA). Therefore, medical insurance costs should be the same for males and females who have the same coverage and demographic characteristics, such as age and location. Regardless, some difference in the amount of insurance cost is expected, which may be justified by different job conditions. Generally, men perform physically harder and more dangerous jobs, which can result in an increase in the price of medical insurance policies.
#
# - <strong>BMI<strong>
#
# While it is prudent to exercise caution when drawing conclusions based solely on Body Mass Index (BMI) as it does not account for important factors such as body composition, muscle mass, and fat distribution, some broad conclusions regarding the overall health of a population can still be inferred from BMI data.
#
# - <strong>Number of children<strong>
#
# It is generally anticipated that the number of children a person has may positively correlate with their medical insurance costs, with higher numbers of children potentially resulting in higher insurance premiums due to a greater likelihood of the family requiring medical care.
#
# - <strong>Smoker status<strong>
#
# A strong positive correlation is expected in regards to the medical insurance cost and positive smoker status.
#
# - <strong>Region<strong>
#
# Since healthcare costs can vary depending on costs of living, provider availability, health status and demographics and state regulations, it is reasonable to expect different medical costs based on region.
#
#
# - <strong>Charges<strong>
#
# There should be tangible differences between medical insurance costs for varying factors such as smoker status, age and number of children.

# %% [markdown]
# ## Conclusions

# %% [markdown]
# The dataset provided comprises of information for 1338 individuals that is organized into seven distinct columns. Each record in the dataset contains details regarding an individual's age, gender, Body Mass Index (BMI), number of children, smoking habits, geographical region of residence, and medical charges.
#
# The average person in this dataset has approximately 39 years. The male to female ratio is 1.02, indicating a nearly equal distribution of individuals identifying as male and female, with no mention of any other genders.
#
# When examining the distribution of the population across different regions, it is apparent that there is a similarity in the number of people living in each area. However, there is a slightly higher population density in the southeast region. Despite this, there are notable differences in the average medical insurance costs across the various regions. The average cost for medical insurance in the southwest region is 12346.94 dollars, which is significantly lower than the average cost in the southeast, which is 14735.41 dollars. The northwest region has a slightly higher average medical insurance cost of 12417.58 dollars, while the northeast region has an average cost of 13406.38 dollars.
#
# These figures show that there are significant differences in the cost of medical insurance across different regions, which can be a crucial factor to consider when assessing the affordability of healthcare in each area.
# <div style="text-align: center;">
#     <img src="RegionalPopulationSizeandAverageMedicalInsuranceCost.png">
# </div>
# Age classification is simplified by grouping people into three categories: young, adult and senior.
#
# <div style="text-align: center;">
#     <img src="AgeDistributionandAverageMedicalInsuranceCost.png">
# </div>
# The average insurance premiums for the aforementioned demographics are 9182.49, 14469.86, and 21063.16 dollars, respectively. Based on the information provided, it can be concluded that the average insurance premiums vary among different demographics. Elderly individuals tend to have the highest insurance premiums, followed by adults and then by younger individuals.
#
# It is important to note that there are numerous variables beyond age that contribute to the overall cost of medical insurance, including the individual's tobacco usage, number of children, Body Mass Index and region of residence.
#
# Based on extensive scientific research indicating the adverse health effects of smoking on individuals, it is reasonable to expect that the average insurance cost for smokers would be significantly higher compared to non-smokers. Empirical evidence supports this notion, as the average insurance cost for smokers in this dataset lies approximately at 32050.23 dollars, whereas that for non-smokers stands at 8434.27 dollars.
#
# It is widely acknowledged that there exists a difference in insurance costs between men and women. After analyzing the medical insurance cost dataset, it has been observed that there is a significant difference in insurance costs between men and women, with men having higher insurance costs by an average of 1387.17 dollars. This difference can be attributed to the higher incidence of men choosing high-risk occupations that expose them to greater danger and occupational hazards. It is important to exercise discretion when considering this generalization, as it is crucial to avoid any potential biases towards women.
# <div style="text-align: center;">
#     <img src="AverageSmokervsNon-SmokerandMalevsFemaleMedicalInsuranceCost.png">
# </div>
# Based on the data analysis of the dataset, it can be concluded that the average number of children per individual in the population is one. As expected, families with a larger number of children are associated with higher insurance premiums. Empirical data supports this notion, with medical costs showing an increasing trend as the number of children in a family increases from none to two or three. However, the trend appears to be reversed for families with four or five children, where there is a decline in medical costs, which is a somewhat unusual finding.
#
# The aforementioned trend persists when examining the impact of tobacco use on insurance costs. In particular, families with a higher number of children and tobacco use are associated with far greater insurance expenses than their non-smoker counterparts. This finding aligns with the expected positive relationship between family size and medical costs. Notably, the observed decrease in medical costs for families with four or five children (and even for families with three children for tobacco users) may warrant further investigation to understand the underlying reasons for this unexpected trend.
#
# After conducting an analysis on the correlation between age and medical insurance cost, it has been found that there is a positive relationship between these two variables. This means that as a person's age increases, their medical insurance cost tends to increase as well. When considering the case of parents with four children who are also tobacco users, it may seem counterintuitive that their medical insurance cost would decrease. However, taking into account the average age of these parents may provide a sensible explanation for this phenomenon. In conclusion, the positive correlation between age and medical insurance cost provides important context for understanding the decrease in medical insurance cost for parents with four children who are also tobacco users. By considering the age datapoint, it becomes clear that this decrease may be explained by the average age of these parents. The average BMI for people who consume tobacco and have five children is 18.3. This may explain the major decrease in medical insurance cost between parents with varying numbers of children, as BMI is clearly considered a key factor in determining insurance costs in this dataset.
# <div style="text-align: center;">
#     <img src="HowChildren,AgenandSmokingAffectMedicalInsuranceCost.png">
# </div>
# The two data points characterized by question marks in the dataset are currently unexplained. These data points share similarities in terms of age, with averages that are higher or similar than those of parents with fewer children. Additionally, their BMI values are similar to those of other parents in the dataset. However, despite these similarities, there is a decrease in medical insurance costs for these two data points. In order to accurately determine the cause of this discrepancy, further data would be required for a more comprehensive analysis.
#
# While the Body Mass Index (BMI) is widely used as a quick and convenient measure of body composition, it may not always provide a comprehensive assessment of an individual's overall health status. A significant proportion of the population in this dataset falls under the category of "above obesity", followed closely by "overweight". There exists a notable positive correlation between BMI and age, which can be attributed to several factors. The natural process of aging often results in a reduction of muscle mass, leading to a decrease in overall physical activity. Additionally, the increasing responsibilities and demands of daily life may contribute to a more sedentary lifestyle as individuals age.
#
# Taken together, these factors may account for the observed association between increasing medical insurance costs and high values of BMI coupled with old age. While analyzing the given dataset, it was found that BMI is given a significant coefficient in the calculation of medical insurance costs, along with other variables such as age, gender, family size, and tobacco usage. Hence, while BMI is taken into consideration for insurance cost calculation, its coefficient should not be overemphasized in comparison to other mentioned variables, which may provide a more comprehensive view of an individual's health and medical needs.
# <div style="text-align: center;">
#     <img src="BodyMassIndexAndAverageAge.png">
# </div>
# In order to gain a more thorough understanding of the dataset, additional analysis could be conducted. This may involve examining a larger dataset to obtain a broader sample size and enhance statistical significance. Furthermore, investigating potential correlations between various health metrics and regional residence could provide valuable insights. By conducting a comprehensive analysis of these factors in relation to each other, a more nuanced understanding of the dataset and its patterns may be obtained. Such an approach would contribute to a more robust and evidence-based analysis, facilitating a more accurate determination of the factors influencing medical insurance costs in the dataset.

# %% [markdown]
# # The Code

# %% [markdown]
# The proposed methodology involves parsing the provided CSV file and extracting each column into individual lists. Each column will be analyzed separately using appropriate statistical and/or data analysis techniques. Interesting factors will be identified and examined across multiple columns to draw meaningful insights.
#
# To simplify the results, visualization techniques will be utilized to present the findings in an easy-to-understand manner. This process will involve creating charts, graphs, and other visual aids to communicate the conclusions of the analysis.
#
# Overall, this approach aims to provide a comprehensive understanding of the data by breaking it down into its constituent parts, analyzing each part in isolation, and then combining the results to draw meaningful conclusions. This methodology will allow for a more thorough and systematic examination of the data, and will help to uncover insights that may have otherwise been overlooked.

# %% [markdown]
# ## Modules

# %%
import csv
import collections
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Unpacking the 'insurance.csv' file

# %%
# open the file, store it into a list, then enumerate the list and print first five elements
with open("insurance.csv") as insurance_file:
    insurance_file_list = list(csv.DictReader(insurance_file))
    for i, row in enumerate(insurance_file_list):
        if i < 5:
            print(i, row)
        else:
            break

# length of the file is equal to number of medical insurance users
print(len(insurance_file_list))
# Out:
# 0 {'age': '19', 'sex': 'female', 'bmi': '27.9', 'children': '0', 'smoker': 'yes', 'region': 'southwest', 'charges': '16884.924'}
# 1 {'age': '18', 'sex': 'male', 'bmi': '33.77', 'children': '1', 'smoker': 'no', 'region': 'southeast', 'charges': '1725.5523'}
# 2 {'age': '28', 'sex': 'male', 'bmi': '33', 'children': '3', 'smoker': 'no', 'region': 'southeast', 'charges': '4449.462'}
# 3 {'age': '33', 'sex': 'male', 'bmi': '22.705', 'children': '0', 'smoker': 'no', 'region': 'northwest', 'charges': '21984.47061'}
# 4 {'age': '32', 'sex': 'male', 'bmi': '28.88', 'children': '0', 'smoker': 'no', 'region': 'northwest', 'charges': '3866.8552'}
# 1338

# %% [markdown]
# ## Organizing the data into lists for easier manipulation

# %%
# an empty list corresponding to every column name
age = []
sex = []
bmi = []
children = []
smoker = []
region = []
charges = []

# open the file, store it into a dictionary, for every column name, store the corresponding row into a list
with open("insurance.csv") as insurance_file:
    insurance_file_dictionary = csv.DictReader(insurance_file)
    for row in insurance_file_dictionary:
        age.append(row["age"])
        sex.append(row["sex"])
        bmi.append(row["bmi"])
        children.append(row["children"])
        smoker.append(row["smoker"])
        region.append(row["region"])
        charges.append(row["charges"])

# check how the lists look in an arbitrarily chosen range        
print(age[365:375])
print(sex[365:375])
print(bmi[365:375])
print(children[365:375])
print(smoker[365:375])
print(region[365:375])
print(charges[365:375])
# Out:
# ['49', '56', '42', '44', '18', '61', '57', '42', '26', '20']
# ['female', 'female', 'female', 'male', 'male', 'female', 'female', 'female', 'male', 'male']
# ['30.78', '32.3', '24.985', '32.015', '30.4', '21.09', '22.23', '33.155', '32.9', '33.33']
# ['1', '3', '2', '2', '3', '0', '0', '1', '2', '0']
# ['no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'no']
# ['northeast', 'northeast', 'northwest', 'northwest', 'northeast', 'northwest', 'northeast', 'northeast', 'southwest', 'southeast']
# ['9778.3472', '13430.265', '8017.06115', '8116.26885', '3481.868', '13415.0381', '12029.2867', '7639.41745', '36085.219', '1391.5287']

# %% [markdown]
# Every list containing numbers has them saved as strings.

# %% [markdown]
# ## Transform lists

# %%
# convert list containing strings as integers to a list of integers
age_clean = []
for a in age:
    age_clean.append(int(a))
    
children_clean = []
for c in children:
    children_clean.append(int(c))

# convert list containing strings as floats to a list of floats
bmi_clean = []
for b in bmi:
    float_b = float(b.replace("'", ""))
    bmi_clean.append(float_b)
    
charges_clean = []
for c in charges:
    float_c = float(c.replace("'", ""))
    charges_clean.append(float_c)

# sort the list from smallest number to highest
age_sorted = sorted(age_clean)

# check how the lists look in an arbitrarily chosen range  
print(age_clean[500:510])
print(sex[500:510])
print(bmi_clean[500:510])
print(children_clean[500:510])
print(smoker[500:510])
print(region[500:510])
print(charges_clean[500:510])
print(age_sorted[550:600])
# Out:
# [29, 43, 51, 19, 38, 37, 22, 21, 24, 57]
# ['male', 'male', 'male', 'male', 'female', 'male', 'male', 'male', 'female', 'female']
# [34.4, 26.03, 23.21, 30.25, 28.93, 30.875, 31.35, 23.75, 25.27, 28.7]
# [0, 0, 1, 0, 1, 3, 1, 2, 0, 0]
# ['yes', 'no', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no']
# ['southwest', 'northeast', 'southeast', 'southeast', 'southeast', 'northwest', 'northwest', 'northwest', 'northeast', 'southwest']
# [36197.699, 6837.3687, 22218.1149, 32548.3405, 5974.3847, 6796.86325, 2643.2685, 3077.0955, 3044.2133, 11455.28]
# [35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 37]

# %% [markdown]
# Lists containing numbers as strings are replaced with lists containing integers/floats.

# %% [markdown]
# ## Analysis

# %%
# calculate average for some number data
def average(data):
    sum_of_data = 0
    for d in data:
        sum_of_data += d
    average = round(sum_of_data / len(data), 2)
    return average

# %% [markdown]
# ## Age

# %%
# average age 
print("The average age is: " + str(average(age_clean)) + " years.")
print()

# new list for age to charge comparison
age_to_charge = list(zip(age_clean, charges_clean))
print(age_to_charge[500:510])

# function for age to charge comparison
def avg_cost_for_age(data):
    young_cost = []
    young_n = 0
    adult_cost = []
    adult_n = 0
    senior_cost = []
    senior_n = 0
    for age, cost in data:
        if age > 0 and age < 30:
            young_cost.append(cost)
            young_n += 1
        elif age >= 30 and age <= 60:
            adult_cost.append(cost)
            adult_n += 1
        else:
            senior_cost.append(cost)
            senior_n += 1
    cost_young = average(young_cost)
    cost_adult = average(adult_cost)
    cost_senior = average(senior_cost)
    
    summary_young = print("There are " + str(young_n) + " people younger than 30 years of age. The average insurance cost for them is: " + str(cost_young) + " dollars.")
    summary_adult = print("There are " + str(adult_n) + " people between 30 and 60 years of age. The average insurance cost for them is: " + str(cost_adult) + " dollars.")
    summary_senior = print("There are " + str(senior_n) + " people older than 60 years of age. The average insurance cost for them is: " + str(cost_senior) + " dollars.")

avg_cost_for_age(age_to_charge)
print()

# new list for age categorization
age_to_gender = list(zip(age_clean, sex))
print(age_to_gender[:5])

# function for age categorization
def categorize_gender_age(data):
    young_male = 0
    young_female = 0
    adult_male = 0
    adult_female = 0
    senior_male = 0
    senior_female = 0
    for age, sex in data:
        if sex == 'male' and age < 30:
            young_male += 1
        elif sex == 'female' and age < 30: 
            young_female += 1
        elif sex == 'male' and age >= 30 and age <= 60:
            adult_male += 1
        elif sex == 'female' and age >= 30 and age <= 60:
             adult_female += 1
        elif sex == 'male' and age > 60:
            senior_male += 1
        else:
            senior_female += 1
    statement = print("There are " + str(young_male) + " males younger than 30 years of age." + "\n" \
                      "There are " + str(young_female) + " females younger than 30 years of age." + "\n" \
                      "There are " + str(adult_male) + " males between 30 and 60 years of age." + "\n" \
                      "There are " + str(adult_female) + " females between 30 and 60 years of age." + "\n" \
                      "There are " + str(senior_male) + " males older than 60 years of age." + "\n" \
                      "There are " + str(senior_female) + " females older than 60 years of age.")
    return statement

categorize_gender_age(age_to_gender)  
print()

# new list to determine average parent age
potential_parents = list(zip(children_clean, age_clean))
print(potential_parents[:5])

# function to determine average parent age
def average_parent_age(data): 
    total_age = 0
    parents = 0 
    for child, age in data:
        if child >= 1:
            total_age += age
            parents += 1
        else:
            pass
    avg_parent_age = round((total_age / parents), 2)
    statement = print("The average age of a person having at least one child is: " + str(avg_parent_age) + " years.")

average_parent_age(potential_parents)
# Out:
# The average age is: 39.21 years.
#
# [(29, 36197.699), (43, 6837.3687), (51, 22218.1149), (19, 32548.3405), (38, 5974.3847), (37, 6796.86325), (22, 2643.2685), (21, 3077.0955), (24, 3044.2133), (57, 11455.28)]
# There are 417 people younger than 30 years of age. The average insurance cost for them is: 9182.49 dollars.
# There are 830 people between 30 and 60 years of age. The average insurance cost for them is: 14469.86 dollars.
# There are 91 people older than 60 years of age. The average insurance cost for them is: 21063.16 dollars.
#
# [(19, 'female'), (18, 'male'), (28, 'male'), (33, 'male'), (32, 'male')]
# There are 216 males younger than 30 years of age.
# There are 201 females younger than 30 years of age.
# There are 416 males between 30 and 60 years of age.
# There are 414 females between 30 and 60 years of age.
# There are 44 males older than 60 years of age.
# There are 47 females older than 60 years of age.
#
# [(0, 19), (1, 18), (3, 28), (0, 33), (0, 32)]
# ...

# %% [markdown]
# ## Sex

# %%
# function that finds the male to female ratio
def gender_ratio(data):
    males = 0
    females = 0
    for d in data:
        if d == 'male':
            males += 1
        else:
            females += 1
    ratio = print("The male to female ration is: " + str(round(males / females, 2)))
    return ratio

gender_ratio(sex)
print()

# function that counts how many men and women are in the dataset
def count_genders(data):
    males = 0
    females = 0
    for d in data:
        if d == 'male':
            males += 1
        else:
            females += 1
    statement = print("There are " + str(males) + " males and " + str(females) + " females in our dataset.")
    return statement

count_genders(sex)
print() 

# counting men and women simplified
males = sex.count('male')
females = sex.count('female')
print(males, females)
# Out:
# The male to female ration is: 1.02
#
# There are 676 males and 662 females in our dataset.
#
# 676 662

# %% [markdown]
# ## BMI

# %%
# average BMI 
print("The average BMI index is: " + str(average(bmi_clean)))
print()

# new list to determine BMI per gender
gender_to_bmi = list(zip(sex, bmi_clean))
print(gender_to_bmi[:5])

# function to determine BMI per gender
def avg_bmi_per_gender(data):
    female_bmi = []
    male_bmi = []
    for gender, bmi in gender_to_bmi:
        if gender == 'male':
            male_bmi.append(bmi)
        else:
            female_bmi.append(bmi)
            
    avg_female = average(female_bmi) 
    avg_male = average(male_bmi)
    statement = print("The average BMI value for females in this dataset is: " + str(avg_female) + ".\n" \
                      "The average BMI value for males in this dataset is: " + str(avg_male) + ".")
    return statement

avg_bmi_per_gender(gender_to_bmi)   
print()

# BMI categorization ; taken from google
#    BMI	     Weight Status 
#Below 18.5	     Underweight
#18.5—24.9	     Healthy Weight
#25.0—29.9	     Overweight
#30.0 and Above  Obesity

# new list to categorize BMI and corresponding average age
age_bmi = list(zip(age_clean, bmi_clean))

# function to categorize BMI and corresponding average age
def bmi_sort(data):
    underweight = 0
    underweight_avg_age = []
    healthy_weight = 0
    healthy_avg_age = []
    overweight = 0
    overweight_avg_age = []
    above_obesity = 0
    above_obesity_avg_age = []
    for a, b in data:
        if b < 18.5:
            underweight += 1
            underweight_avg_age.append(a)
        elif b >= 18.5 and b <= 24.9:
            healthy_weight += 1
            healthy_avg_age.append(a)
        elif b >= 25.0 and b <= 29.9:
            overweight += 1
            overweight_avg_age.append(a)
        else:
            above_obesity += 1
            above_obesity_avg_age.append(a)
            
    avg_age_underweight = average(underweight_avg_age)
    avg_age_healthy = average(healthy_avg_age)
    avg_age_overweight = average(overweight_avg_age)
    avg_age_above_obesity = average(above_obesity_avg_age)
    
    statement = print("Underweight: " + str(underweight) + " - Average age: " + str(avg_age_underweight) + " years." + "\n" \
                      "Healthy weight: " + str(healthy_weight) +" - Average age: " + str(avg_age_healthy) + " years." + "\n" \
                      "Overweight: " + str(overweight) + " - Average age: " + str(avg_age_overweight) + " years." + "\n" \
                      "Above obesity: " + str(above_obesity) + " - Average age: " + str(avg_age_above_obesity) + " years.")
    return statement

bmi_sort(age_bmi)
# Out:
# The average BMI index is: 30.66
#
# [('female', 27.9), ('male', 33.77), ('male', 33.0), ('male', 22.705), ('male', 28.88)]
# The average BMI value for females in this dataset is: 30.38.
# The average BMI value for males in this dataset is: 30.94.
#
# Underweight: 20 - Average age: 32.35 years.
# Healthy weight: 222 - Average age: 36.75 years.
# Overweight: 377 - Average age: 38.9 years.
# Above obesity: 719 - Average age: 40.32 years.

# %% [markdown]
# ## Children

# %%
# average number of children per parent
print("The average number of children per parent is: " + str(int(round(average(children_clean), 0))))
print()

# maximum number of children a parent has
print("The maximum number of children a parent in this dataset has is: " + str(max(children_clean)))
print()

# new list to determine average charge per child and corresponding parent age and bmi
child_parent_charge_bmi_age = list(zip(children_clean, age_clean, bmi_clean, charges_clean))
print(child_parent_charge_bmi_age[:5])

def charge_per_child(data):
    avg_charge_zero = []
    parent_age_zero = []
    bmi_zero = []
    avg_charge_one = []
    parent_age_one = []
    bmi_one = []
    avg_charge_two = []
    parent_age_two = []
    bmi_two = []
    avg_charge_three = []
    parent_age_three = []
    bmi_three = []
    avg_charge_four = []
    parent_age_four = []
    bmi_four = []
    avg_charge_five = []
    parent_age_five = []
    bmi_five = []
    for child, age, bmi, cost in data:
        if child == 0:
            avg_charge_zero.append(cost)
            parent_age_zero.append(age)
            bmi_zero.append(bmi)
        elif child == 1:
            avg_charge_one.append(cost)
            parent_age_one.append(age)
            bmi_one.append(bmi)
        elif child == 2:
            avg_charge_two.append(cost)
            parent_age_two.append(age)
            bmi_two.append(bmi)
        elif child == 3:
            avg_charge_three.append(cost)
            parent_age_three.append(age)
            bmi_three.append(bmi)
        elif child == 4:
            avg_charge_four.append(cost)
            parent_age_four.append(age)
            bmi_four.append(bmi)
        else:
            avg_charge_five.append(cost)
            parent_age_five.append(age)
            bmi_five.append(bmi)
    
    avg_age_zero = average(parent_age_zero)
    avg_age_one = average(parent_age_one)
    avg_age_two = average(parent_age_two)
    avg_age_three = average(parent_age_three)
    avg_age_four = average(parent_age_four)
    avg_age_five = average(parent_age_five)
    
    avg_charge_zero = average(avg_charge_zero)
    avg_charge_one = average(avg_charge_one)
    avg_charge_two = average(avg_charge_two)
    avg_charge_three = average(avg_charge_three)
    avg_charge_four = average(avg_charge_four)
    avg_charge_five = average(avg_charge_five)
    
    avg_bmi_zero = average(bmi_zero)
    avg_bmi_one = average(bmi_one)
    avg_bmi_two = average(bmi_two)
    avg_bmi_three = average(bmi_three)
    avg_bmi_four = average(bmi_four)
    avg_bmi_five = average(bmi_five)
    
    statement =  print("The average age for people who have no children is " + str(avg_age_zero) + " years. Their BMI is: " + str(avg_bmi_zero) + ". Their average medical insurance cost is: " + str(avg_charge_zero) + " dollars.\n" \
                       "The average age for people who have one child is " + str(avg_age_one) + " years. Their BMI is: " + str(avg_bmi_one) + ".  Their average medical insurance cost is: " + str(avg_charge_one) + " dollars.\n" \
                       "The average age for people who have two children is " + str(avg_age_two) + " years. Their BMI is: " + str(avg_bmi_two) + ".  Their average medical insurance cost is: " + str(avg_charge_two) + " dollars.\n" \
                       "The average age for people who have three children is " + str(avg_age_three) + " years. Their BMI is: " + str(avg_bmi_three) + ".  Their average medical insurance cost is: " + str(avg_charge_three) + " dollars.\n" \
                       "The average age for people who have four children is " + str(avg_age_four) + " years. Their BMI is: " + str(avg_bmi_four) + ".  Their average medical insurance cost is: " + str(avg_charge_four) + " dollars.\n" \
                       "The average age for people who have five children is " + str(avg_age_five) + " years. Their BMI is: " + str(avg_bmi_five) + ".  Their average medical insurance cost is: " + str(avg_charge_five) + " dollars.")
    return statement

charge_per_child(child_parent_charge_bmi_age)
# Out:
# The average number of children per parent is: 1
#
# The maximum number of children a parent in this dataset has is: 5
#
# [(0, 19, 27.9, 16884.924), (1, 18, 33.77, 1725.5523), (3, 28, 33.0, 4449.462), (0, 33, 22.705, 21984.47061), (0, 32, 28.88, 3866.8552)]
# The average age for people who have no children is 38.44 years. Their BMI is: 30.55. Their average medical insurance cost is: 12365.98 dollars.
# The average age for people who have one child is 39.45 years. Their BMI is: 30.62.  Their average medical insurance cost is: 12731.17 dollars.
# The average age for people who have two children is 39.45 years. Their BMI is: 30.98.  Their average medical insurance cost is: 15073.56 dollars.
# The average age for people who have three children is 41.57 years. Their BMI is: 30.68.  Their average medical insurance cost is: 15355.32 dollars.
# The average age for people who have four children is 39.0 years. Their BMI is: 31.39.  Their average medical insurance cost is: 13850.66 dollars.
# ...

# %% [markdown]
# ## Smoker

# %%
# function to determine smokers to non-smokers 
def smoker_ratio(data):
    yes = 0
    no = 0
    for d in data:
        if d == 'yes':
            yes += 1
        else:
            no += 1
    ratio = print("The smoker to non-smoker ration is: " + str(round(yes / no, 2)))
    return ratio

smoker_ratio(smoker)
print()

# counting smokers and non-smokers
smoke = smoker.count('yes')
no_smoke = smoker.count('no')
print("There are " + str(smoke) + " smokers and " + str(no_smoke) + " non-smokers in our dataset.")
print()

# new list to determine charge for smokers 
smoker_to_charge = list(zip(smoker, charges_clean))
print(smoker_to_charge[500:510])

# function to determine average cost for smokers
def avg_cost_for_smoker(data):
    total_smoker = []
    total_nonsmoker = [] 
    for smoker, charge in data:
        if smoker == 'yes':
            total_smoker.append(charge)
        else:
            total_nonsmoker.append(charge)
    diff = (average(total_smoker) - average(total_nonsmoker))
    statement = print("The average insurance cost for smokers is " + str(average(total_smoker)) + " dollars.\n" \
                      "The average insurance cost for non-smokers is " + str(average(total_nonsmoker)) + " dollars.\n" \
                      "Their difference is " + str(diff) + " dollars.")
    return statement    

avg_cost_for_smoker(smoker_to_charge)
print()

# new list to determine smokers per gender
gender_to_smoker = list(zip(sex, smoker))
print(gender_to_smoker[:5])

def smoker_per_gender(data):
    female_smokers = 0
    male_smokers = 0
    for gender, smoker in data:
        if gender == 'female' and smoker == 'yes':
            female_smokers += 1
        elif gender == 'male' and smoker == 'yes':
            male_smokers += 1
    statement = print("There are " + str(female_smokers) + " female smokers and " + str(male_smokers) + " male smokers in the given dataset.")
    return statement

smoker_per_gender(gender_to_smoker)
print()

# new list to determine average charge per child for smoker/non-smoker parents and corresponding age and bmi
parents = list(zip(children_clean, age_clean, smoker, charges_clean, bmi_clean))
print(parents[:5])

# function to determine average charge per child for smoker parents and corresponding age and bmi
def smoker_parents(data):
    zero_count = 0
    zero_charge = []
    zero_age = []
    bmi_zero = []
    one_count = 0
    one_charge = []
    one_age = []
    bmi_one = []
    two_count = 0
    two_charge = []
    two_age = []
    bmi_two = []
    three_count = 0
    three_charge = []
    three_age = []
    bmi_three = []
    four_count = 0
    four_charge = []
    four_age = []
    bmi_four = []
    five_count = 0
    five_charge = []
    five_age = []
    bmi_five = [] 
    for child, age, smoke, charge, bmi in data:
        if child == 0 and smoke == 'yes':
            zero_count += 1
            zero_charge.append(charge)
            zero_age.append(age)
            bmi_zero.append(bmi)
        elif child == 1 and smoke == 'yes':
            one_count += 1
            one_charge.append(charge)
            one_age.append(age)
            bmi_one.append(bmi)
        elif child == 2 and smoke == 'yes':
            two_count += 1
            two_charge.append(charge)
            two_age.append(age)
            bmi_two.append(bmi)
        elif child == 3 and smoke == 'yes':
            three_count += 1
            three_charge.append(charge)
            three_age.append(age)
            bmi_three.append(bmi)
        elif child == 4 and smoke == 'yes':
            four_count += 1
            four_charge.append(charge)
            four_age.append(age)
            bmi_four.append(bmi)
        elif child == 5 and smoke == 'yes':
            five_count += 1
            five_charge.append(charge)
            five_age.append(age)
            bmi_five.append(bmi)
            
    avg_age_zero = average(zero_age)
    avg_age_one = average(one_age)
    avg_age_two = average(two_age)
    avg_age_three = average(three_age)
    avg_age_four = average(four_age)
    avg_age_five = average(five_age)
    
    avg_charge_zero = average(zero_charge)
    avg_charge_one = average(one_charge)
    avg_charge_two = average(two_charge)
    avg_charge_three = average(three_charge)
    avg_charge_four = average(four_charge)
    avg_charge_five = average(five_charge)
    
    avg_bmi_zero = average(bmi_zero)
    avg_bmi_one = average(bmi_one)
    avg_bmi_two = average(bmi_two)
    avg_bmi_three = average(bmi_three)
    avg_bmi_four = average(bmi_four)
    avg_bmi_five = average(bmi_five)
    
    
    statement =  print("The average age for people who smoke and have no children is " + str(avg_age_zero) + " years. Their BMI is: " + str(avg_bmi_zero) + ".Their average medical insurance cost is: " + str(avg_charge_zero) + " dollars.\n" \
                       "The average age for people who smoke and have one child is " + str(avg_age_one) + " years. Their BMI is: " + str(avg_bmi_one) + ". Their average medical insurance cost is: " + str(avg_charge_one) + " dollars.\n" \
                       "The average age for people who smoke and have two children is " + str(avg_age_two) + " years. Their BMI is: " + str(avg_bmi_two) + ". Their average medical insurance cost is: " + str(avg_charge_two) + " dollars.\n" \
                       "The average age for people who smoke and have three children is " + str(avg_age_three) + " years. Their BMI is: " + str(avg_bmi_three) + ". Their average medical insurance cost is: " + str(avg_charge_three) + " dollars.\n" \
                       "The average age for people who smoke and have four children is " + str(avg_age_four) + " years. Their BMI is: " + str(avg_bmi_four) + ". Their average medical insurance cost is: " + str(avg_charge_four) + " dollars.\n" \
                       "The average age for people who smoke and have five children is " + str(avg_age_five) + " years. Their BMI is: " + str(avg_bmi_five) + ". Their average medical insurance cost is: " + str(avg_charge_five) + " dollars.")
                      
    return statement    

smoker_parents(parents)
print()

# function to determine average charge per child for non-smoker parents and corresponding age and bmi
def non_smoker_parents(data):
    zero_charge = []
    zero_age = []
    bmi_zero = []
    one_charge = []
    one_age = []
    bmi_one = []
    two_charge = []
    two_age = [] 
    bmi_two = [] 
    three_charge = []
    three_age = []
    bmi_three = []
    four_charge = []
    four_age = []
    bmi_four = []
    five_charge = []
    five_age = []
    bmi_five = []
    for child, age, smoke, charge, bmi in data:
        if child == 0 and smoke == 'no':
            zero_charge.append(charge)
            zero_age.append(age)
            bmi_zero.append(bmi)
        elif child == 1 and smoke == 'no':
            one_charge.append(charge)
            one_age.append(age)
            bmi_one.append(bmi)
        elif child == 2 and smoke == 'no':
            two_charge.append(charge)
            two_age.append(age)
            bmi_two.append(bmi)
        elif child == 3 and smoke == 'no':   
            three_charge.append(charge)
            three_age.append(age)
            bmi_three.append(bmi)
        elif child == 4 and smoke == 'no':
            four_charge.append(charge)
            four_age.append(age)
            bmi_four.append(bmi)
        elif child == 5 and smoke == 'no':
            five_charge.append(charge)
            five_age.append(age)
            bmi_five.append(bmi)
            
    avg_age_zero = average(zero_age)
    avg_age_one = average(one_age)
    avg_age_two = average(two_age)
    avg_age_three = average(three_age)
    avg_age_four = average(four_age)
    avg_age_five = average(five_age)
    
    avg_charge_zero = average(zero_charge)
    avg_charge_one = average(one_charge)
    avg_charge_two = average(two_charge)
    avg_charge_three = average(three_charge)
    avg_charge_four = average(four_charge)
    avg_charge_five = average(five_charge)
    
    avg_bmi_zero = average(bmi_zero)
    avg_bmi_one = average(bmi_one)
    avg_bmi_two = average(bmi_two)
    avg_bmi_three = average(bmi_three)
    avg_bmi_four = average(bmi_four)
    avg_bmi_five = average(bmi_five)
    
    statement =  print("The average age for people who don't smoke and have no children is " + str(avg_age_zero) + " years. Their BMI is: " + str(avg_bmi_zero) + " Their average medical insurance cost is: " + str(avg_charge_zero) + " dollars.\n" \
                       "The average age for people who don't smoke and have one child is " + str(avg_age_one) + " years. Their BMI is: " + str(avg_bmi_one) + "  Their average medical insurance cost is: " + str(avg_charge_one) + " dollars.\n" \
                       "The average age for people who don't smoke and have two children is " + str(avg_age_two) + " years. Their BMI is: " + str(avg_bmi_two) + "  Their average medical insurance cost is: " + str(avg_charge_two) + " dollars.\n" \
                       "The average age for people who don't smoke and have three children is " + str(avg_age_three) + " years. Their BMI is: " + str(avg_bmi_three) + "  Their average medical insurance cost is: " + str(avg_charge_three) + " dollars.\n" \
                       "The average age for people who don't smoke and have four children is " + str(avg_age_four) + " years. Their BMI is: " + str(avg_bmi_four) + "  Their average medical insurance cost is: " + str(avg_charge_four) + " dollars.\n" \
                       "The average age for people who don't smoke and have five children is " + str(avg_age_five) + " years. Their BMI is: " + str(avg_bmi_five) + "  Their average medical insurance cost is: " + str(avg_charge_five) + " dollars.")
                      
    return statement    

non_smoker_parents(parents)
# Out:
# The smoker to non-smoker ration is: 0.26
#
# There are 274 smokers and 1064 non-smokers in our dataset.
#
# [('yes', 36197.699), ('no', 6837.3687), ('yes', 22218.1149), ('yes', 32548.3405), ('no', 5974.3847), ('no', 6796.86325), ('no', 2643.2685), ('no', 3077.0955), ('no', 3044.2133), ('no', 11455.28)]
# The average insurance cost for smokers is 32050.23 dollars.
# The average insurance cost for non-smokers is 8434.27 dollars.
# Their difference is 23615.96 dollars.
#
# [('female', 'yes'), ('male', 'no'), ('male', 'no'), ('male', 'no'), ('male', 'no')]
# There are 115 female smokers and 159 male smokers in the given dataset.
#
# [(0, 19, 'yes', 16884.924, 27.9), (1, 18, 'no', 1725.5523, 33.77), (3, 28, 'no', 4449.462, 33.0), (0, 33, 'no', 21984.47061, 22.705), (0, 32, 'no', 3866.8552, 28.88)]
# The average age for people who smoke and have no children is 36.79 years. Their BMI is: 30.54.Their average medical insurance cost is: 31341.36 dollars.
# ...

# %% [markdown]
# ## Region

# %%
# function to isolate uniqe regions
def regions(data):
    unique_regions = []
    for d in data:
        if d.title() not in unique_regions:
            unique_regions.append(d.title())
    region_str = "\n".join(unique_regions)
    statement = print("There are " + str(len(unique_regions)) + " different regions in the 'insurance.csv' file:" + "\n" + region_str)
    return statement

regions(region)
print()

# function to count people per region
def count_people_per_region(data):
    counts = collections.Counter(data)
    return dict(counts)
print(count_people_per_region(region))
print()

# new list to count male and female residents of each region
gender_to_region = list(zip(sex, region))
print(gender_to_region[:5])

# function to count male and female residents of each region
def gender_count_per_region(data): 
    southwest_male = 0
    southwest_female = 0
    southeast_male = 0
    southeast_female = 0
    northwest_male = 0
    northwest_female = 0
    northeast_male = 0
    northeast_female = 0
    for gender, region in data:
        if gender == 'male' and region == 'southwest':
            southwest_male += 1
        elif gender == 'female' and region == 'southwest':
            southwest_female += 1
        elif gender == 'male' and region == 'southeast':
            southeast_male += 1
        elif gender == 'female' and region == 'southeast':
            southeast_female += 1
        elif gender == 'male' and region == 'northwest':
            northwest_male += 1
        elif gender == 'female' and region == 'northwest':
            northwest_female += 1
        elif gender == 'male' and region == 'northeast':
            northeast_male += 1
        else:
            northeast_female += 1
    statement = print("There are " + str(southwest_male) + " males in the southwest." + "\n" \
                      "There are " + str(southwest_female) + " females in the southwest." + "\n" \
                      "There are " + str(southeast_male) + " males in the southeast." + "\n" \
                      "There are " + str(southeast_female) + " females in the southeast." + "\n" \
                      "There are " + str(northwest_male) + " males in the northwest." + "\n" \
                      "There are " + str(northwest_female) + " females in the northwest." + "\n" \
                      "There are " + str(northeast_male) + " males in the northeast." + "\n" \
                      "There are " + str(northeast_female) + " females in the northeast.")
    return statement

gender_count_per_region(gender_to_region)
print()
# Out:
# There are 4 different regions in the 'insurance.csv' file:
# Southwest
# Southeast
# Northwest
# Northeast
#
# {'southwest': 325, 'southeast': 364, 'northwest': 325, 'northeast': 324}
#
# [('female', 'southwest'), ('male', 'southeast'), ('male', 'southeast'), ('male', 'northwest'), ('male', 'northwest')]
# There are 163 males in the southwest.
# There are 162 females in the southwest.
# There are 189 males in the southeast.
# There are 175 females in the southeast.
# There are 161 males in the northwest.
# There are 164 females in the northwest.
# There are 163 males in the northeast.
# There are 161 females in the northeast.

# %% [markdown]
# ## Charges

# %%
# average charge 
print("The average insurance cost is: " + str(average(charges_clean)) + " dollars.")
print()

# maximum charge in the dataset
print(max(charges_clean))
print()

# new list to determine charge per gender
gender_to_charge = list(zip(sex, charges_clean))
print(gender_to_charge[:5])

# new function to determine charge per gender
def gender_cost(data):
    female_cost_total = []
    male_cost_total = []
    for gender, charge in gender_to_charge:
        if gender == 'female':
            female_cost_total.append(charge)
        else:
            male_cost_total.append(charge)
            
    female_cost_avg = average(female_cost_total) 
    male_cost_avg = average(male_cost_total)  
    diff = abs(female_cost_avg - male_cost_avg)
    statement = print("Average female insurance cost is: " + str(female_cost_avg) + " dollars.\n" \
            "Average male insurance cost is: " + str(male_cost_avg) + " dollars.\n" \
            "The difference between average female and average male insurance cost is: " + str(diff) + " dollars.")
    return statement

gender_cost(gender_to_charge)
print()

# new list to analyze charge by region
region_to_charge = list(zip(region, charges_clean))
print(region_to_charge[:5])

# function to analyze charge by region
def charge_by_region(data):
    southwest_charge = []
    southeast_charge = []
    northwest_charge = []
    northeast_charge = []
    for region, charge in data:
        if region == 'southwest':
            southwest_charge.append(charge)
        elif region == 'southeast':
            southeast_charge.append(charge)
        elif region == 'northwest':
            northwest_charge.append(charge)
        else:
            northeast_charge.append(charge)
   
    avg_southwest = average(southwest_charge)
    avg_southeast = average(southeast_charge)
    avg_northwest = average(northwest_charge)
    avg_northeast = average(northeast_charge)
    
    statement = print("The average medical insurance cost in southwest is: " + str(avg_southwest) + " dollars." + "\n" \
                      "The average medical insurance cost in southeast is: " + str(avg_southeast) + " dollars." + "\n" \
                      "The average medical insurance cost in northwest is: " + str(avg_northwest) + " dollars." + "\n" \
                      "The average medical insurance cost in northeast is: " + str(avg_northeast) + " dollars.")
    return statement

charge_by_region(region_to_charge)
print()

# new list to count parents with n children in each region
parents_per_region = list(zip(region, children_clean))
print(parents_per_region[:5])

# function to count parents with n children in each region
def parents_with_n_children_per_region(data):
    # create a dictionary to store counts per region and value
    count_dict = {}
    # loop through the list of tuples
    for region, children in data:
        # Check if the region is already in the dictionary
        if region not in count_dict:
            # If not, add the region with an empty dictionary as the value
            count_dict[region] = {}
    
        # check if the children value is already a key in the nested dictionary
        if children not in count_dict[region]:
            # if not, add the children value with count 1
            count_dict[region][children] = 1
        else:
            # if it is, increment the count by 1
            count_dict[region][children] += 1

    # sort the regions alphabetically
    sorted_regions = sorted(count_dict.keys())

    # print the counts per region and value
    for region in sorted_regions:
        print("Region:", region.capitalize())
        # loop through the children values from 0 to 5
        for children in range(6):
            # check if the children value is in the nested dictionary
            if children in count_dict[region]:
                parents = count_dict[region][children]
            else:
                count = 0
            print("Children:", children, "Parents:", parents)

parents_with_n_children_per_region(parents_per_region)
# Out:
# The average insurance cost is: 13270.42 dollars.
#
# 63770.42801
#
# [('female', 16884.924), ('male', 1725.5523), ('male', 4449.462), ('male', 21984.47061), ('male', 3866.8552)]
# Average female insurance cost is: 12569.58 dollars.
# Average male insurance cost is: 13956.75 dollars.
# The difference between average female and average male insurance cost is: 1387.17 dollars.
#
# [('southwest', 16884.924), ('southeast', 1725.5523), ('southeast', 4449.462), ('northwest', 21984.47061), ('northwest', 3866.8552)]
# The average medical insurance cost in southwest is: 12346.94 dollars.
# The average medical insurance cost in southeast is: 14735.41 dollars.
# The average medical insurance cost in northwest is: 12417.58 dollars.
# The average medical insurance cost in northeast is: 13406.38 dollars.
#
# [('southwest', 0), ('southeast', 1), ('southeast', 3), ('northwest', 0), ('northwest', 0)]
# Region: Northeast
# Children: 0 Parents: 147
# Children: 1 Parents: 77
# Children: 2 Parents: 51
# ...

# %% [markdown]
# ## Visualization

# %% [markdown]
# As a novice in data visualization, and programming in general, I have limited familiarity with creating visual representations of data. To ensure that my code is more comprehensible and interpretable, I have provided detailed comments in this section. The purpose of these comments is to elaborate on the steps taken and to provide context for the code. By doing so, I aim to improve the clarity and effectiveness of my code, despite my limited expertise in data visualization.

# %% [markdown]
# ### Regional Population Size and Average Medical Insurance Cost

# %%
# create a new figure and axis object
fig, ax = plt.subplots()
# define the bottom of each bar in the bar chart
bottom = np.zeros(4)  
# define the width of the bars in the bar chart
width = 0.4 

# define the categories for the regions
category = ('Southwest', 'Northwest', 'Northeast', 'Southeast')

# define the number of men and women in each region
genders = { 'Men': np.array([163, 161, 163, 189]), 'Women': np.array([162, 164, 161, 175])}

# define the average insurance cost per region (in thousands of dollars)
insurance_costs = np.array([12.3, 12.4, 13.4, 14.7]) 

# define the colors for the bars representing men and women
colors = ['#1e90ff', '#FFC0CB'] 

# loop through the genders dictionary and create a stacked bar chart
for i, (gender, genders) in enumerate(genders.items()):
    p = ax.bar(category, genders, width, label=gender, bottom=bottom, color=colors[i])
    bottom += genders
    ax.bar_label(p, label_type='center', weight='bold') 

# make the border lines thicker
for spine in ax.spines.values():
    spine.set_linewidth(1) 

# add the title to the plot and make it bold ; set the font size, thickness, direction, and length of the tick marks on the axes
ax.set_title('Regional Population Size and Average Medical Insurance Cost', weight='bold') 
ax.tick_params(axis='both', which='major', labelsize=10, width=1.1, direction='out', length=5, pad=5)

# make the x-axis and y-axis labels bold
for tick in ax.get_xticklabels():
    tick.set_weight('bold') 
for tick in ax.get_yticklabels():
    tick.set_weight('bold')  
    
# add a label to the x-axis and y-axis and set y-axis range
plt.xlabel("Region", weight='bold')
plt.ylabel("N(People)", weight='bold')
plt.ylim([0, 400])

# add a legend to the plot
legend = plt.legend(frameon=False)
for text in legend.get_texts():
    text.set_fontweight('bold')

# create a twin axes with a second y-axis
ax2 = ax.twinx()
# add a label to the right y-axis
ax2.set_ylabel("Medical Insurance Cost (thousands)", weight='bold', color='black')
# set the font size, thickness, direction, length, and color of the tick marks on the right y-axis
ax2.tick_params(axis='y', which='major', labelsize=10, width=1, direction='out', length=5, pad=5, colors='black')
# set the color of the right y-axis
ax2.spines['right'].set_color('black')

# add the line plot to the right y-axis
line = ax2.plot(category, insurance_costs, '--o', color='black', linewidth=2, markersize=5)
# add text labels to the line plot
for x, y in zip(category, insurance_costs):
    ax2.text(x, y+0.015, f'{y:.1f}', ha='center', va='bottom', fontweight='bold', color='red') 

# bold the y-axis values on the right side
for tick in ax2.get_yticklabels():
    tick.set_weight('bold')

# save the graph
plt.savefig("RegionalPopulationSizeandAverageMedicalInsuranceCost.png", dpi=125, bbox_inches='tight')
# display the graph
plt.show()

# %% [markdown]
# ### Age Distribution and Average Medical Insurance Cost

# %%
# create a new figure and axis object
fig, ax = plt.subplots()
# define the bottom of each bar in the bar chart
bottom = np.zeros(3)
# define the width of the bars in the bar chart
width = 0.4

# define the categories for the regions
category = ('Young(<30)', 'Adult(30-60)', 'Senior(>60)')

# define the number of men and women in each region
genders = {'Men': np.array([216, 416, 44]), 'Women': np.array([201, 414, 47])}

# define the charge of men and women in each region
charge_by_age_category = np.array([9.2, 14.5, 21.0])

# define the colors for the bars representing men and women
colors = ['#1e90ff', '#FFC0CB'] 

# plot the bars for men and women
for i, (gender, genders) in enumerate(genders.items()):
    p = ax.bar(category, genders, width, label=gender, bottom=bottom, color=colors[i])
    bottom += genders
    # add text labels to the bars
    ax.bar_label(p, label_type='center', weight='bold')  

# make the border lines thicker
for spine in ax.spines.values():
    spine.set_linewidth(1)  

# set title, ax labels and tics
ax.set_title('Age Distribution and Average Medical Insurance Cost', weight='bold')
ax.tick_params(axis='both', which='major', labelsize=10, width=1.1, direction='out', length=5, pad=5)
plt.ylabel("N(People)", weight='bold')
plt.xlabel("Age Group", weight='bold')

# make the x-axis tics bold
for tick in ax.get_xticklabels():
    tick.set_weight('bold')  
# make the y-axis tics bold
for tick in ax.get_yticklabels():
    tick.set_weight('bold')  

# set the legend and make the text bold
legend = plt.legend(frameon=False,loc='upper left')
for text in legend.get_texts():
    text.set_fontweight('bold')


# create a twin axes with a second y-axis
ax2 = ax.twinx()

# set the label and color for the second y-axis ; set the tick parameters for the second y-axis
ax2.set_ylabel("Medical Insurance Cost (thousands)", weight='bold')
ax2.tick_params(axis='y', which='major', labelsize=10, width=1, direction='out', length=5, pad=5)

# add the line plot for the average medical insurance cost
line = ax2.plot(category, charge_by_age_category, '--o', color='black', linewidth=2, markersize=5)

# add text labels to the line
for x, y in zip(category, charge_by_age_category):
    ax2.text(x, y+0.015, f'{y:.1f}', ha='center', va='bottom', fontweight='bold', color='red') 

# make the y-axis tics on the right side bold
for tick in ax2.get_yticklabels():
    tick.set_weight('bold')
    
# adjust spacing to prevent overlap and ensure legend is visible
plt.tight_layout()

# save the graph
plt.savefig("AgeDistributionandAverageMedicalInsuranceCost.png", dpi=125, bbox_inches='tight')

# display the graph
plt.show()

# %% [markdown]
# ### How Children, Age and Smoking Affect Medical Insurance Cost

# %%
# define the data for plot
num_children = [0, 1, 2, 3, 4, 5]

avg_insurance_cost = [12.3, 12.7, 15.0, 15.3, 13.8, 8.7]
avg_age = [38.44, 39.45, 39.45, 41.57, 39.0, 35.61]

non_smoker_parent_avg_insurance_cost = [7.6, 8.3, 9.4, 9.6, 12.1, 8.1]
non_smoker_avg_age = [38.86, 39.37, 39.42, 41.82, 40.23, 35.41]

smoker_parent_avg_insurance_cost = [31.3, 31.8, 33.8, 32.7, 26.5, 19.0]
smoker_avg_age = [36.79, 39.8, 39.53, 40.79, 30.0, 39.0]

# plot the data
plt.plot(num_children, smoker_parent_avg_insurance_cost, marker='s', markersize=5, color='#808080')
plt.plot(num_children, avg_insurance_cost, marker='o', markersize=5,  color='#32CD32')
plt.plot(num_children, non_smoker_parent_avg_insurance_cost, marker='D', markersize=5, color='#1e90ff')

# add average smoker and non smoker age under insurance cost data point
for i in range(len(num_children)):
    plt.text(num_children[i]-0.2, smoker_parent_avg_insurance_cost[i]-1.5, str(smoker_avg_age[i]) + 'y', ha='left', va='center', weight='bold', fontsize='small', color='#808080')
    plt.text(num_children[i]-0.2, avg_insurance_cost[i]+2, str(avg_age[i]) + 'y', ha='left', va='center', weight='bold', fontsize='small', color='#32CD32')
    plt.text(num_children[i]-0.2, non_smoker_parent_avg_insurance_cost[i]-1.5, str(non_smoker_avg_age[i]) + 'y', ha='left', va='center', weight='bold', fontsize='small', color='#1e90ff')


# set the plot title, x-axis and y-axis labels, and axis limits
plt.title("How Children, Age and Smoking Affect Medical Insurance Cost", weight='bold')
plt.xlabel("Number of Children", weight='bold')
plt.ylabel("Medical Insurance Cost (thousands)", weight='bold')
plt.xlim([-0.3, 5.3])
plt.ylim([5, 35])

# add annotations to the plot
plt.text(num_children[4]+0.01, avg_insurance_cost[4]+0.1, str('?'), ha='center', va='bottom', weight='bold', fontsize='x-large', color='red')
plt.text(num_children[3]+0.01, smoker_parent_avg_insurance_cost[3]+0.1, str('?'), ha='center', va='bottom', weight='bold', fontsize='x-large', color='red')

# style certain datapoints
plt.plot(num_children[4], avg_insurance_cost[4], marker='o', markersize=5, color='red')
plt.plot(num_children[3], smoker_parent_avg_insurance_cost[3], marker='s', markersize=5, color='red')

# customize the plot appearance
plt.rcParams['axes.edgecolor'] = 'black'
plt.rcParams['axes.linewidth'] = 1
plt.xticks(num_children, weight='bold')
plt.yticks(weight='bold')
plt.tick_params(width=1.2, length=5)

# add legend with labels and bold the text to manually set position
legend = ['Smoker Parent Average', 'Overall Average', 'Non-Smoker Parent Average']
plt.legend(frameon=False, labels=legend, prop={'weight': 'bold'}, loc=(0.02, 0.5))

# save the plot to a file and display it
plt.savefig("HowChildren,AgenandSmokingAffectMedicalInsuranceCost.png", dpi=125, bbox_inches='tight')

# display the graph
plt.show()

# %% [markdown]
# ### Average Smoker vs Non-Smoker and Male vs Female Insurance Cost

# %%
# create a figure and axis object
fig, ax = plt.subplots()

# define the data to be plotted
users = ['Smoker', 'Non-Smoker', 'Men', 'Women']
counts = [32.0, 8.4, 13.9, 12.5]
bar_colors = ['#808080', '#32CD32', '#1e90ff', '#FFC0CB']

# plot the data as a bar chart
ax.bar(users, counts, color=bar_colors)

# set the title, x-axis, y-axis and tics
ax.set_title('Average Smoker vs Non-Smoker and Male vs Female Medical Insurance Cost', fontweight='bold')
ax.set_xlabel('Users', fontweight='bold')
ax.set_ylabel('Medical Insurance Cost (thousands)', fontweight='bold')
plt.xticks(weight='bold')
plt.yticks(weight='bold')
plt.tick_params(width=1.1, length=5)

# make box bold and set width
ax.spines['right'].set_linewidth(1)
ax.spines['top'].set_linewidth(1)
ax.spines['bottom'].set_linewidth(1)
ax.spines['left'].set_linewidth(1)

# calculate the difference in cost between smoker and non-smoker, and between male and female
diff_smoker = counts[0] - counts[1]
diff_male = counts[2] - counts[3]

# add double-sided arrows to the chart to show the differences in cost, and annotate the arrow with the difference amount
#1 
x1, y1 = 0.5, counts[0]
x2, y2 = 0.5, counts[1]
dx, dy = x2 - x1, y2 - y1
ax.annotate('', xy=(x1, y1), xytext=(x2, y2), arrowprops=dict(arrowstyle='<->', lw=1.5, mutation_scale=15, color='red'))
ax.text(0.7, (y1 + y2)/2, f'{abs(diff_smoker):.1f}k', ha='center', va='bottom', fontweight='bold', color='red')

#2
x1, y1 = 2, counts[2]
x2, y2 = 3, counts[3]
dx, dy = x2 - x1, y2 - y1
ax.annotate('', xy=(x1, y1), xytext=(x2, y2), arrowprops=dict(arrowstyle='<->', lw=1.5, mutation_scale=15, color='red'))
ax.text(2.55, 13.5, f'{abs(diff_male):.1f}k', ha='center', va='bottom', fontweight='bold', color='red')

# save and show the plot
plt.savefig("AverageSmokervsNon-SmokerandMalevsFemaleMedicalInsuranceCost.png", dpi=125, bbox_inches='tight')

# display the graph
plt.show()

# %% [markdown]
# ### Body Mass Index And Average Age

# %%
# create a new figure and axis
fig, ax = plt.subplots()

# define the data, sizes and colors
labels = ['Underweight', 'Healthy weight', 'Overweight', 'Above obesity']
sizes = [20, 222, 377, 719]
colors = ['dodgerblue', 'green', 'orange', 'red']
avg_age = [32.35, 36.75, 38.90, 40.32]

# define the explode parameter to highlight some slice
explode = [0, 0, 0, 0.1]

# plot the pie chart with the specified parameters and set the title for the plot
ax.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=120, textprops={'fontweight': 'bold', 'fontsize': 16, 'va': 'center'})

ax.set_title('Body Mass Index And Average Age', fontsize=18, fontweight='bold')

legend = ax.legend(avg_age, title="Average Age", loc="lower right", frameon=False, prop={'weight': 'bold'}, bbox_to_anchor=(1, 0, 0.5, 1))
legend.get_title().set_fontproperties({'weight': 'bold', 'size': 14})
for text in legend.get_texts():
    text.set_fontsize(14)

# save and show the plot
plt.savefig("BodyMassIndexAndAverageAge.png", dpi=125, bbox_inches='tight')

# display the graph
plt.show()
